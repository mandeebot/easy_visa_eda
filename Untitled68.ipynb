# %% [markdown]
# <a href="https://colab.research.google.com/github/mandeebot/easy_visa_eda/blob/main/Untitled68.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data = pd.read_csv('EasyVisa.csv')
data.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
data.describe().T
# Out:
#                    count          mean           std        min       25%  \
# no_of_employees  25480.0   5667.043210  22877.928848   -26.0000   1022.00
# yr_of_estab      25480.0   1979.409929     42.366929  1800.0000   1976.00
# prevailing_wage  25480.0  74455.814592  52815.942327     2.1367  34015.48
#
#                       50%          75%        max
# no_of_employees   2109.00    3504.0000  602069.00
# yr_of_estab       1997.00    2005.0000    2016.00
# prevailing_wage  70308.21  107735.5125  319210.27

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
def plot(feature,t_plot):
  total = len(feature)
  for p in t_plot.patches:
    percentage ='{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()/2 - 0.05
    y = p.get_y() + p.get_height()
    ax.annotate(percentage,(x,y),size=12)
  plt.show()

# %%
#univariate nalysis of the case_status
plt.figure(figsize=(10,6))
sb.countplot(x='case_status',data=data)

# %%
data.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
#univariate analysis of the continent feature
plt.figure(figsize=(10,6))
sb.countplot(x='continent',data = data)

# %%
#univariate analysis of the education level
data['education_of_employee'].value_counts()
# Out:
# Bachelor's     10234
# Master's        9634
# High School     3420
# Doctorate       2192
# Name: education_of_employee, dtype: int64

# %%
plt.figure(figsize=(10,6))
sb.countplot(x='education_of_employee',data=data)

# %%
#univariate analysis of the job experence
data['has_job_experience'].value_counts()
# Out:
# Y    14802
# N    10678
# Name: has_job_experience, dtype: int64

# %%
plt.figure(figsize=(10,6))
sb.countplot(x='has_job_experience',data=data)

# %%
#univariate analysis of the prevailing wage feature

plt.figure(figsize=(10,6))
sb.histplot(x='prevailing_wage',data=data);

# %%
data['yr_of_estab'].value_counts()
# Out:
# 1998    1134
# 2005    1051
# 2001    1017
# 2007     994
# 1999     870
#         ...
# 1842       6
# 1846       4
# 1822       4
# 1810       3
# 1824       2
# Name: yr_of_estab, Length: 199, dtype: int64

# %%
plt.figure(figsize=(10,6))
sb.histplot(data['yr_of_estab'])

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
#case study vs education level

plt.figure(figsize=(10,6))
sb.countplot(x='case_status',hue='education_of_employee',data=data)

# %%
data['education_of_employee'].value_counts()
# Out:
# Bachelor's     10234
# Master's        9634
# High School     3420
# Doctorate       2192
# Name: education_of_employee, dtype: int64

# %%
#case status vs continent
plt.figure(figsize=(11,7))
sb.countplot(x='case_status',hue='continent',data=data);

# %%
data['continent'].value_counts()
# Out:
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: continent, dtype: int64

# %%
#job experience vs case status
plt.figure(figsize=(10,6))
sb.countplot(x='has_job_experience',hue='case_status',data=data)

# %%
#case status vs wages
plt.figure(figsize=(10,6))
sb.boxplot(x='case_status', y='prevailing_wage',data=data)

# %%
#region of employment vs no of employees vs continent
plt.figure(figsize=(14,6))
sb.barplot(x='region_of_employment',y='no_of_employees',hue ='continent',data=data)

# %%
#requires trainig vs no employees vs continent
plt.figure(figsize=(14,6))
sb.barplot(x='requires_job_training',y='no_of_employees',hue ='continent',data=data)

# %% [markdown]
# MULTIVARIATE ANALYSIS

# %%
#no employees vs yr of establishment vs prevailing wage
num_var = ['no_of_employees','yr_of_estab','prevailing_wage']

# %%
samples = np.random.choice(data.shape[0],500,replace=False)
df_sample = data.reindex(samples)

#pair grid
sb.pairplot(df_sample)

# %%
## heatmeap to see the correlation between features. 
# Generate a mask for the upper triangle (taken from seaborn example gallery)
mask = np.zeros_like(data.corr(), dtype=bool)
mask[np.triu_indices_from(mask)] = True
plt.subplots(figsize = (15,12))
sb.heatmap(data.corr(), 
            annot=True,
            mask = mask,
            cmap = 'RdBu', ## in order to reverse the bar replace "RdBu" with "RdBu_r"
            linewidths=.9, 
            linecolor='white',
            fmt='.2g',
            center = 0,
            square=True);
plt.title("Correlations Among Features", y = 1.03,fontsize = 20, pad = 40);

# %%
from pandas_profiling import ProfileReport
